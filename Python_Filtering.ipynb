# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("F:\Poulta\iris.csv")

# %%
df.head()
# Out:
#          Name  sepal_length  sepal_width  petal_length  petal_width species
# 0   Ali Abbas           5.1          3.5           1.4          0.2  setosa
# 1   M Hussain           4.9          3.0           1.4          0.2  setosa
# 2    M Hassan           4.7          3.2           1.3          0.2  setosa
# 3   Ali Akbar           4.6          3.1           1.5          0.2  setosa
# 4  Ali Asghar           5.0          3.6           1.4          0.2  setosa

# %%
df.iloc[100:150]
# Out:
#             Name  sepal_length  sepal_width  petal_length  petal_width  \
# 100   Haider Ali           6.3          3.3           6.0          2.5
# 101  Mujtaba Ali           5.8          2.7           5.1          1.9
# 102   Ali Hassan           7.1          3.0           5.9          2.1
# 103    Ali Abbas           6.3          2.9           5.6          1.8
# 104    M Hussain           6.5          3.0           5.8          2.2
# 105     M Hassan           7.6          3.0           6.6          2.1
# 106    Ali Akbar           4.9          2.5           4.5          1.7
# 107   Ali Asghar           7.3          2.9           6.3          1.8
# 108    Qasim Ali           6.7          2.5           5.8          1.8
# 109  Hussain Ali           7.2          3.6           6.1          2.5
# 110   Haider Ali           6.5          3.2           5.1          2.0
# 111  Mujtaba Ali           6.4          2.7           5.3          1.9
# ...

# %%
a = df["species"] == 'versicolor'
df[a]
# Out:
#            Name  sepal_length  sepal_width  petal_length  petal_width  \
# 50    M Hussain           7.0          3.2           4.7          1.4
# 51     M Hassan           6.4          3.2           4.5          1.5
# 52    Ali Akbar           6.9          3.1           4.9          1.5
# 53   Ali Asghar           5.5          2.3           4.0          1.3
# 54    Qasim Ali           6.5          2.8           4.6          1.5
# 55  Hussain Ali           5.7          2.8           4.5          1.3
# 56   Haider Ali           6.3          3.3           4.7          1.6
# 57  Mujtaba Ali           4.9          2.4           3.3          1.0
# 58   Ali Hassan           6.6          2.9           4.6          1.3
# 59    Ali Abbas           5.2          2.7           3.9          1.4
# 60    M Hussain           5.0          2.0           3.5          1.0
# 61     M Hassan           5.9          3.0           4.2          1.5
# ...

# %%
petal_width = (df["petal_width"] > 1) & (df["species"] == 'versicolor')
df[petal_width]
# Out:
#            Name  sepal_length  sepal_width  petal_length  petal_width  \
# 50    M Hussain           7.0          3.2           4.7          1.4
# 51     M Hassan           6.4          3.2           4.5          1.5
# 52    Ali Akbar           6.9          3.1           4.9          1.5
# 53   Ali Asghar           5.5          2.3           4.0          1.3
# 54    Qasim Ali           6.5          2.8           4.6          1.5
# 55  Hussain Ali           5.7          2.8           4.5          1.3
# 56   Haider Ali           6.3          3.3           4.7          1.6
# 58   Ali Hassan           6.6          2.9           4.6          1.3
# 59    Ali Abbas           5.2          2.7           3.9          1.4
# 61     M Hassan           5.9          3.0           4.2          1.5
# 63   Ali Asghar           6.1          2.9           4.7          1.4
# 64    Qasim Ali           5.6          2.9           3.6          1.3
# ...

# %%
df[['First Name','Last Name']] = df.Name.str.split(" ",expand = True)
df
# Out:
#             Name  sepal_length  sepal_width  petal_length  petal_width  \
# 0      Ali Abbas           5.1          3.5           1.4          0.2
# 1      M Hussain           4.9          3.0           1.4          0.2
# 2       M Hassan           4.7          3.2           1.3          0.2
# 3      Ali Akbar           4.6          3.1           1.5          0.2
# 4     Ali Asghar           5.0          3.6           1.4          0.2
# ..           ...           ...          ...           ...          ...
# 145   Haider Ali           6.7          3.0           5.2          2.3
# 146  Mujtaba Ali           6.3          2.5           5.0          1.9
# 147   Ali Hassan           6.5          3.0           5.2          2.0
# 148  Mujtaba Ali           6.2          3.4           5.4          2.3
# 149   Ali Hassan           5.9          3.0           5.1          1.8
#
#        species First Name Last Name
# 0       setosa        Ali     Abbas
# 1       setosa          M   Hussain
# ...

# %%
z = df['Last Name'] == 'Ali'
df[z]
# Out:
#             Name  sepal_length  sepal_width  petal_length  petal_width  \
# 5      Qasim Ali           5.4          3.9           1.7          0.4
# 6    Hussain Ali           4.6          3.4           1.4          0.3
# 7     Haider Ali           5.0          3.4           1.5          0.2
# 8    Mujtaba Ali           4.4          2.9           1.4          0.2
# 15     Qasim Ali           5.7          4.4           1.5          0.4
# ..           ...           ...          ...           ...          ...
# 143    Qasim Ali           6.8          3.2           5.9          2.3
# 144  Hussain Ali           6.7          3.3           5.7          2.5
# 145   Haider Ali           6.7          3.0           5.2          2.3
# 146  Mujtaba Ali           6.3          2.5           5.0          1.9
# 148  Mujtaba Ali           6.2          3.4           5.4          2.3
#
#        species First Name Last Name
# 5       setosa      Qasim       Ali
# 6       setosa    Hussain       Ali
# ...

# %%
versicolor = (df["species"] == 'versicolor')
df[versicolor]
# Out:
#            Name  sepal_length  sepal_width  petal_length  petal_width  \
# 50    M Hussain           7.0          3.2           4.7          1.4
# 51     M Hassan           6.4          3.2           4.5          1.5
# 52    Ali Akbar           6.9          3.1           4.9          1.5
# 53   Ali Asghar           5.5          2.3           4.0          1.3
# 54    Qasim Ali           6.5          2.8           4.6          1.5
# 55  Hussain Ali           5.7          2.8           4.5          1.3
# 56   Haider Ali           6.3          3.3           4.7          1.6
# 57  Mujtaba Ali           4.9          2.4           3.3          1.0
# 58   Ali Hassan           6.6          2.9           4.6          1.3
# 59    Ali Abbas           5.2          2.7           3.9          1.4
# 60    M Hussain           5.0          2.0           3.5          1.0
# 61     M Hassan           5.9          3.0           4.2          1.5
# ...

# %%
df.species.str.split("i").str[1]

# %%
df[['Fir','sec']] = df.species.str.split("i",expand = True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8412\855328459.py in <module>
# ----> 1 df[['Fir','sec']] = df.species.str.split("i",expand = True)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3641             self._setitem_frame(key, value)
#    3642         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3643             self._setitem_array(key, value)
#    3644         elif isinstance(value, DataFrame):
#    3645             self._set_item_frame_value(key, value)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3683
#    3684             if isinstance(value, DataFrame):
# -> 3685                 check_key_length(self.columns, key, value)
#    3686                 for k1, k2 in zip(key, value.columns):
# ...

# %%
df['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
import numpy as np
import pandas as pd

# %%
x = pd.DataFrame({"col1":np.arange(1,20,2)},index=[9,8,7,6,0,1,2,3,4,5])
x
# Out:
#    col1
# 9     1
# 8     3
# 7     5
# 6     7
# 0     9
# 1    11
# 2    13
# 3    15
# 4    17
# 5    19

# %%
x.iloc[0:5]
# Out:
#    col1
# 9     1
# 8     3
# 7     5
# 6     7
# 0     9

# %%
x.loc[0:5]
# Out:
#    col1
# 0     9
# 1    11
# 2    13
# 3    15
# 4    17
# 5    19
